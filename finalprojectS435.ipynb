# %%
#Run this code to see a visual summary of my overall project 

from PIL import Image
import os.path

script_dir = os.path.dirname(os.path.abspath('.Downloads'))
im = Image.open(os.path.join(script_dir, 'finalproject.PNG'))
im.show()

# %%
#Step 1: Data cleaning and processing

#####Importing 1st Data set#####    
#directory 
import os, sys
os.getcwd
#loading data
import numpy as np
import pandas as pd
datab=pd.read_csv('FootballData.csv')
dataf=pd.read_csv('BasketballData.csv')
datas=pd.read_csv('Addtl.csv')

# %%
######### DATA CLEANING ##################

# %%
###Exploring Data Basketball###

#check first 5 lines of the data
datab.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Classification Name  Classification Other  Sanction Code  \
# 0       AZ                    1                   NaN              1
# 1       AL                    1                   NaN              1
# 2       TX                    1                   NaN              1
# 3       MA                    1                   NaN              1
# 4       SC                    1                   NaN              1
#
#   Sanction Name  Male Undergraduates  ...  \
# 0          NCAA                14876  ...
# ...

# %%
#check rows
datab.tail()
# Out:
#      ID2  Survey Year  UNITID                             Institution Name  \
# 145  146         2017  198419                              Duke University
# 146  147         2017  134097                     Florida State University
# 147  148         2017  139755  Georgia Institute of Technology-Main Campus
# 148  149         2017  151351               Indiana University-Bloomington
# 149  150         2017  153603                        Iowa State University
#
#     State CD  Classification Name  Classification Other  Sanction Code  \
# 145       NC                    1                   NaN              1
# 146       FL                    1                   NaN              1
# 147       GA                    1                   NaN              1
# 148       IN                    1                   NaN              1
# 149       IA                    1                   NaN              1
#
#     Sanction Name  Male Undergraduates  ...  \
# ...

# %%
#check info
datab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 65 columns):
# ID2                                                                     150 non-null int64
# Survey Year                                                             150 non-null int64
# UNITID                                                                  150 non-null int64
# Institution Name                                                        150 non-null object
# State CD                                                                150 non-null object
# Classification Name                                                     150 non-null int64
# Classification Other                                                    0 non-null float64
# Sanction Code                                                           150 non-null int64
# Sanction Name                                                           150 non-null object
# ...

# %%
#printing columns names 
print(list(datab.columns.values))
# Out:
# ['ID2', 'Survey Year', 'UNITID', 'Institution Name', 'State CD', 'Classification Name', 'Classification Other', 'Sanction Code', 'Sanction Name', 'Male Undergraduates', 'Female Undergraduates', 'Total Undergraduates', 'Sport Code', 'Sport Name', '# Participants Mens Team', '# Participants Womens Team', '# Participants Men Coed Team', '# Participants Women Coed Team', 'Total # Participants Mens Team/Men Coed Team', 'Total # Participants Womens Team/Women Coed Team', 'Operating Expenses per Participant/Mens Team', 'Operating Expenses per Team/Mens Team', 'Operating Expenses per Participant/Womens Team', 'Operating Expenses per Team/Womens Team', 'Total Operating Expenses Mens Team and Womens Team', 'Operating Expenses per Participant/Men Coed Team', 'Operating Expenses per Team/Men Coed Team', 'Operating Expenses per Participant/Women Coed Team', 'Operating Expenses per Team/Women Coed Team', 'Total Operating Expenses Men Coed Team/Women Coed Team', 'Revenues Mens Team', 'Revenues Wome
# ...

# %%
###removing N/A's###
databv1=datab.loc[:, datab.columns.notnull()]
databv1.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Classification Name  Classification Other  Sanction Code  \
# 0       AZ                    1                   NaN              1
# 1       AL                    1                   NaN              1
# 2       TX                    1                   NaN              1
# 3       MA                    1                   NaN              1
# 4       SC                    1                   NaN              1
#
#   Sanction Name  Male Undergraduates  ...  \
# 0          NCAA                14876  ...
# ...

# %%
###removing columns "...."###
datav3 = databv1.drop(databv1.columns[[11]], axis=1, inplace=True)

# %%
#check first 5 lines of the data
dataf.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Classification Name  Classification Other  Sanction Code  \
# 0       AZ                    1                   NaN              1
# 1       AL                    1                   NaN              1
# 2       TX                    1                   NaN              1
# 3       MA                    1                   NaN              1
# 4       SC                    1                   NaN              1
#
#   Sanction Name  Male Undergraduates  ...  \
# 0          NCAA                14876  ...
# ...

# %%
###Cleaning the Data Basketball - removing N/A's###
datafv1=dataf.dropna(axis='columns')
datafv1.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Classification Name  Sanction Code Sanction Name  \
# 0       AZ                    1              1          NCAA
# 1       AL                    1              1          NCAA
# 2       TX                    1              1          NCAA
# 3       MA                    1              1          NCAA
# 4       SC                    1              1          NCAA
#
#    Male Undergraduates  Female Undergraduates  ...  \
# 0                14876                  16059  ...
# ...

# %%
###Merge Data Sets###
finaldf = databv1.append(datafv1)
finaldf
# Out:
# C:\Users\Maddie\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#       Womens Team Average Annual Institutional Salary per Assistant Coach  \
# 0                                                43216
# 1                                                39843
# 2                                                56009
# 3                                                16770
# 4                                                49300
# 5                                                37672
# 6                                                33226
# 7                                                35025
# 8                                                34933
# ...

# %%
finaldfv1=finaldf.dropna(axis='columns')
finaldfv1
# Out:
#       Womens Team Average Annual Institutional Salary per Assistant Coach  \
# 0                                                43216
# 1                                                39843
# 2                                                56009
# 3                                                16770
# 4                                                49300
# 5                                                37672
# 6                                                33226
# 7                                                35025
# 8                                                34933
# 9                                                53547
# 10                                               46145
# 11                                               45402
# 12                                               45380
# 13                                               24645
# 14                                               56111
# 15                                               39846
# ...

# %%
###Exploring Additional Salary Data###

#check first 5 lines of the data
datas.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Mens Team Average Annual Institutional Salary per Head Coach  \
# 0       AZ                                             289145
# 1       AL                                             387819
# 2       TX                                             356815
# 3       MA                                              75950
# 4       SC                                             218827
#
#    Mens Team Number of Head Coaches Included in Average  \
# 0                                                  8
# ...

# %%
###Data Addtl Salary- removing N/A's###
datasv1=datas.dropna(axis='columns')
datasv1.head()
# Out:
#    ID2  Survey Year  UNITID                              Institution Name  \
# 0    1         2003  104151  Arizona State University at the Tempe Campus
# 1    2         2003  100858                 Auburn University Main Campus
# 2    3         2003  223232                             Baylor University
# 3    4         2003  164924                                Boston College
# 4    5         2003  217882                            Clemson University
#
#   State CD  Mens Team Average Annual Institutional Salary per Head Coach  \
# 0       AZ                                             289145
# 1       AL                                             387819
# 2       TX                                             356815
# 3       MA                                              75950
# 4       SC                                             218827
#
#    Mens Team Number of Head Coaches Included in Average  \
# 0                                                  8
# ...

# %%
finalfv1 = finaldfv1.append(datasv1)
finalfv1
# Out:
# C:\Users\Maddie\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#       Womens Team Average Annual Institutional Salary per Assistant Coach  \
# 0                                                43216
# 1                                                39843
# 2                                                56009
# 3                                                16770
# 4                                                49300
# 5                                                37672
# 6                                                33226
# 7                                                35025
# 8                                                34933
# ...

# %%
################ DATA ANALYSIS ###################################

# %%
###STEP 2 Analysis### 
### do within visualization ###
import numpy as np
meansa = finaldfv1.loc[:,"Mens Team Athletic Student Aid"].mean()
meanmp = finaldfv1.loc[:,"# Participants Mens Team"].mean()
print(meanmp)
print(meansa)
meansa1 = finaldfv1.loc[:,"Mens Team Athletic Student Aid"].sum()
meanmp1 = finaldfv1.loc[:,"# Participants Mens Team"].sum()
meansa1/meanmp1
# Out:
# 66.21
# 1164216.4333333333
# 17583.694809444696

# %%
import numpy as np
meanhcs = finaldfv1.loc[:,"Mens Team Average Annual Institutional Salary per Head Coach"].mean()
print(meanhcs)
sumfte = finaldfv1.loc[:,"Mens Team Average Annual Institutional Salary per FTE"].sum()
sumnfte = finaldfv1.loc[:,"Mens Team Number of FTEs Included in Average"].sum()
print(sumfte)
print(sumnfte)
avfte = (sumfte/sumnfte)
print(avfte)
# Out:
# 612759.4933333333
# 209451568
# 2111.86
# 99178.71828625003

# %%
#test
np.random.seed(1)
x = np.random.randint(0, 50, 1000)
y = x + np.random.normal(0, 10, 1000)
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
corrfinal = finaldfv1.corr(method='pearson')

# %%
datasv1.describe()
# Out:
#               ID2  Survey Year         UNITID  \
# count  150.000000   150.000000     150.000000
# mean    75.500000  2010.000000  158827.200000
# std     43.445368     4.334968   40939.341725
# min      1.000000  2003.000000  100858.000000
# 25%     38.250000  2006.000000  134097.000000
# 50%     75.500000  2010.000000  152477.000000
# 75%    112.750000  2014.000000  198419.000000
# max    150.000000  2017.000000  223232.000000
#
#        Mens Team Average Annual Institutional Salary per Head Coach  \
# count                                       1.500000e+02
# mean                                        6.127595e+05
# std                                         3.932135e+05
# min                                         7.595000e+04
# 25%                                         2.945725e+05
# 50%                                         5.598820e+05
# 75%                                         8.314725e+05
# max                                         1.756515e+06
#
# ...

# %%
##NCAA##
from requests import get
url = 'http://www.ncaa.org/about/resources/media-center/news'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
#   "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:article="http://ogp.me/ns/article#"
#   xmlns:book="http://ogp.me/ns/book#"
#   xmlns:profile="http://ogp.me/ns/profile#"
#   xmlns:video="http://ogp.me/ns/video#"
#   xmlns:product="http://ogp.me/ns/product#"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
#Twitter
import requests
url = 'https://twitter.com/NCAA' 
data = requests.get(url) 
#print(data.text)

# %%
#extracting tweets#
all_tweets = []
html = BeautifulSoup(data.text, 'html.parser')
timeline = html.select('#timeline li.stream-item')
for tweet in timeline:
    tweet_id = tweet['data-item-id']
    tweet_text = tweet.select('p.tweet-text')[0].get_text()
    all_tweets.append({"id": tweet_id, "text": tweet_text})

# %%
#check
print(all_tweets)

# %%
import re
htmlv = html.body
counter = htmlv.text
Counting_times = (counter.count("win"))
print(Counting_times)

# %%
import requests

URL = 'https://www.google.com/search?q=ncaa&rlz=1C1EJFC_enUS844US844&oq=ncaa&aqs=chrome..69i57j69i60l3j69i59j35i39.1690j1j7&sourceid=chrome&ie=UTF-8'


def run(**params):
    response = requests.get(URL.format(**params))
    print (response.content, response.status_code)


run(query="NCAA", month=1, from_day=2, to_day=2, year=18)

# %%
###########Data Visulization#############

# %%
###Webscrap CBS SPORTS###
from bs4 import BeautifulSoup
import requests
import time

# finds all news headings from CBS College Football Sports.
print("")
print("*** CBS College Football Headlines. ***")
print('----------------------------------')
print("")
source_code = requests.get('https://www.cbssports.com/college-football/')
html_code = source_code.text
soup = BeautifulSoup(html_code, 'lxml')
headings = soup.find_all(['h1', 'h2', 'h3'])

for i in headings:
    time.sleep(10)
    print(i.text)
    
###Webscrap CBS SPORTS###
from bs4 import BeautifulSoup
import requests
import time

# finds all news headings from CBS College Basketball Sports.
print("")
print("*** CBS College Basketball Headlines. ***")
print('----------------------------------')
print("")
source_code = requests.get('https://www.cbssports.com/college-basketball/')
html_code = source_code.text
soup = BeautifulSoup(html_code, 'lxml')
headings = soup.find_all(['h1', 'h2', 'h3'])

for i in headings:
    time.sleep(10)
    print(i.text)
print('----------End of update------------------------')
# Out:
# *** CBS College Football Headlines. ***
# ----------------------------------
#
#
#                                     Backers, expectations high for Ryan Day
#
#
#                                     Top 25 Power Five coaches in 2019
#
#
#                                     Ranking the rest from 65-26
#
#
#                         Top Florida recruit in 2019 class transferring out
#
#
#                         Kansas State lands UNC's ex-leading rusher
#
#
#                         College football coaching tiers ahead of the season
#
#
#                         Florida schedules future series with Colorado
#
#
#                         Saban predicts how 'Game of Thrones' will end
#
#
#                         Trump suggests waiver for service academy athletes
#
#
#                                     Best quarterback succession plans
#
#
#                                     Lessons learned this spring in the SEC
#
#
# NFL the last thing on Lawrence's mind
#
#
# ...

# %%
###Webscrap NCAA###
from bs4 import BeautifulSoup
import requests
import time

# finds all news headings from CBS College Football Sports.
print("")
print('----------------------------------')
print("")
source_code = requests.get('https://www.ncaa.com/news')
html_code = source_code.text
soup = BeautifulSoup(html_code, 'lxml')
headings = soup.find_all(['h1', 'h2', 'h3'])

for i in headings:
    time.sleep(10)
    print(i.text)
print('----------End of update------------------------')
# Out:
# ----------------------------------
#
# TRENDING:
# NCAA.com – The Official Website of NCAA Championships
#
# 3 can’t-miss games in the first round of the NCAA DI tournament
#
#         Lacrosse Championships
#
# DII men's lacrosse
# 8 teams advance to DII men's lacrosse quarterfinals
# DIII women's lacrosse
# DIII women's lacrosse championship bracket revealed
# DIII men's lacrosse
# DIII men's lacrosse championship third round field is set
#
#         Softball News
#
# DI Softball
# 3 big questions ahead of the 2019 NCAA softball selection show
# DII softball
# 2019 DII softball tournament: Brackets, schedules, scores
# DIII softball
# 2019 DIII Softball Tournament: Bracket, schedule, scores for regionals
#
#         Top News
#
# DI softball
# Oklahoma gets unanimous No. 1, top teams shuffle in softball poll
# DI baseball
# UCLA stays on top, Oklahoma State vaults back in poll
# DII women's tennis
# 2019 NCAA Division II women’s tennis championship selections
# DI Women's Golf
# ...

# %%
from bs4 import BeautifulSoup
import requests
import time

# finds all news headings from google news.
print("")
print('----------------------------------')
print("")
source_code = requests.get('https://www.google.com/search?q=ncaa&rlz=1C1EJFC_enUS844US844&oq=ncaa&aqs=chrome..69i57j69i60l3j69i59j35i39.1690j1j7&sourceid=chrome&ie=UTF-8')
html_code = source_code.text
soup = BeautifulSoup(html_code, 'lxml')
headings = soup.find_all(['h1', 'h2', 'h3'])

for i in headings:
    time.sleep(10)
    print(i.text)
print('------End of update----------------------------')
# Out:
# ----------------------------------
#
#
# Search Options
# NCAA.org - The Official Site of the NCAA
# Eligibility Center
# NCAA Apps Login
# NCAA.com – The Official Website of NCAA Championships | NCAA ...
# NCAA men's college basketball scores, news, rankings | NCAA.com
# 2019 NCAA Men's Lacrosse Tournament: Bracket, schedule, scores ...
# National Collegiate Athletic Association - Wikipedia
# NCAA (@NCAA) | Twitter
# National Collegiate Athletic Association - The New York Times
# NCAA Tournament 2019 - March Madness - CBSSports.com
# Detroit Mercy not eligible for NCAA tournament after APR score
# ------End of update----------------------------

# %%
from bs4 import BeautifulSoup
import requests
import time

# finds all news headings from espn news.
print("")
print('----------------------------------')
print("")
source_code = requests.get('http://www.espn.com/college-sports')
html_code = source_code.text
soup = BeautifulSoup(html_code, 'lxml')
headings = soup.find_all(['h1', 'h2', 'h3'])

for i in headings:
    time.sleep(10)
    print(i.text)
    
print('------End of update----------------------------')
# Out:
# ----------------------------------
#
# ESPN
# Favorites
# Customize ESPN
# Fantasy
# ESPN Sites
# ESPN Apps
# Follow ESPN
# NCAA Division I men's lacrosse tournament: Schedule, results, news
# NCAA Men's Lacrosse
# PSU men's lax earns No. 1 seed in NCAA tourney
# NCAA Softball
# Tori's tour of Texas A&M's Davis Diamond
# NCAA Men's Baseball
# No. 6 Bulldogs rally late to secure win
# NCAA Softball
# Gators moving on after dramatic win over Gamecocks
# NCAA - Other
# Waller named new UCLA gymnastics coach
# Track and Field
# Georgia runner impaled by javelin, has surgery
# NCAA - Other
# APR report shows athletes' scores remain steady
# NCAA - Other
# Nebraska tennis coach admits to drunken driving
# NCAA Softball
# 7Innings podcast: Stella
# NCAA Softball
# Smiling Shemiah Sanchez and her painful pursuit of SEC softball stardom
# NCAA Men's Baseball
# Auburn falls to UAB
# NCAA Men's Baseball
# No. 24 Tennessee gets back on track
# NCAA Men's Baseball
# ...

# %%
def correlation_matrix(finaldfv1):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 300)
    cax = ax1.imshow(finaldfv1.corr(), interpolation="nearest", cmap="hot")
    ax1.grid(True)
    plt.title('Correlation')
    labels=['Mens Team Average Annual Institutional Salary per FTE',        'Mens Team Athletic Student Aid','Total Revenues Mens Team and Men Coed Team','Mens Team Average Annual Institutional Salary per Head Coach']
    ax1.set_xticklabels(labels,fontsize=3)
    ax1.set_yticklabels(labels,fontsize=12)
    fig.colorbar(cax, ticks=[.1,1])
    plt.show()

correlation_matrix(finaldfv1)

# %%
#details of map
print(corrfinal)
plt.show()
# Out:
#                                                      Womens Team Average Annual Institutional Salary per Assistant Coach  \
#  Womens Team Average Annual Institutional Salar...                                       1.000000e+00
#  Womens Team Average Annual Institutional Salar...                                       8.186854e-01
# # Participants Mens Team                                                                 4.196763e-02
# Classification Name                                                                               NaN
# Expenses Mens Team                                                                       4.109502e-01
# Female Undergraduates                                                                    2.761536e-01
# ID2                                                                                      6.334153e-01
# Male Undergraduates                                                                      2.449785e-01
# ...

# %%
def highlight_max(corrfinal, color='yellow'):
    '''
   
    '''
    attr = 'background-color: {}'.format(color)
    if finaldfv1.ndim == 1:  
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  
        is_max = data == data.max().max()
        return pd.corrfinal(np.where(is_max, attr, ''),
                            index=finaldfv1.index, columns=corrfinal.columns)

# %%
#Overall small pockets of strongly correlated variables
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def correlation_matrix(finaldfv1):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(finaldfv1.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Correlation')
    labels=[]
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(finaldfv1)

# %%
#stats comprehensive and succinct summary 
datasv1.describe()
# Out:
#               ID2  Survey Year         UNITID  \
# count  150.000000   150.000000     150.000000
# mean    75.500000  2010.000000  158827.200000
# std     43.445368     4.334968   40939.341725
# min      1.000000  2003.000000  100858.000000
# 25%     38.250000  2006.000000  134097.000000
# 50%     75.500000  2010.000000  152477.000000
# 75%    112.750000  2014.000000  198419.000000
# max    150.000000  2017.000000  223232.000000
#
#        Mens Team Average Annual Institutional Salary per Head Coach  \
# count                                       1.500000e+02
# mean                                        6.127595e+05
# std                                         3.932135e+05
# min                                         7.595000e+04
# 25%                                         2.945725e+05
# 50%                                         5.598820e+05
# 75%                                         8.314725e+05
# max                                         1.756515e+06
#
# ...

# %%
import sys
sys.version
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)
